# %%
#dictionary

student = {"id":1,"name":"alice","marks":79}
student
# Out:
# {'id': 1, 'name': 'alice', 'marks': 79}

# %%
type(student)
# Out:
# dict

# %%
"student name:",student["name"]
# Out:
# ('student name:', 'alice')

# %%
#type 1 to access the key from the items
serach_values=79
key_with_value=[]
for key, value in student.items():
    if value==serach_values:
        key_with_value.append(key)
print("key for value",serach_values,":",key_with_value)
# Out:
# key for value 79 : ['marks']

# %%
#typ2 list comprehension
serach_values=79
key_with_values=[key for key , value in student.items() if value == serach_values]
print("list comprehnsion",key_with_values)
# Out:
# list comprehnsion ['marks']

# %%
student.update({"age":20})
student
# Out:
# {'id': 1, 'name': 'alice', 'marks': 79, 'age': 20}

# %%
student["city"] = ["pune"]
student
# Out:
# {'id': 1, 'name': 'alice', 'marks': 79, 'age': 20, 'city': ['pune']}

# %%
#add the item with known or countable index or keys
new_student={}

for key,value in student.items():
    new_student[key]=value
    if  key=="name":
        new_student["standard"]=8
print(new_student)
# Out:
# {'id': 1, 'name': 'alice', 'standard': 8, 'marks': 79, 'age': 20, 'city': ['pune']}

# %%
student = {'id': 1, 'name': 'alice', 'marks': 79, 'age': 20, 'city': ['pune']}
del student["city"]
student
# Out:
# {'id': 1, 'name': 'alice', 'marks': 79, 'age': 20}

# %%
students={
    101:{"name":"alice","age":20,"department":"it"},
    102:{"name":"bob","age":20,"department":"cs"},
    103:{"name":"joe","age":21,"department":"aids"}
}
students
# Out:
# {101: {'name': 'alice', 'age': 20, 'department': 'it'},
#  102: {'name': 'bob', 'age': 20, 'department': 'cs'},
#  103: {'name': 'joe', 'age': 21, 'department': 'aids'}}

# %%
students[101]
# Out:
# {'name': 'alice', 'age': 20, 'department': 'it'}

# %%
 print("no of students",len(students))
# Out:
# no of students 3

# %%
marks = {"alice " : 77,"bob" : 89 ,"Charlie":67}
marks
# Out:
# {'alice ': 77, 'bob': 89, 'Charlie': 67}

# %% [raw]
# #Assignment _day4

# %%
students = {
    "Amit": 85,
    "Neha": 92,
    "Rahul": 78,
    "Priya": 88,
    "Sonal": 90
}
students#1
# Out:
# {'Amit': 85, 'Neha': 92, 'Rahul': 78, 'Priya': 88, 'Sonal': 90}

# %%
print(students["Neha"])#2
# Out:
# 92

# %%
students["Karan"] = 81

students #3
# Out:
# {'Amit': 85, 'Neha': 92, 'Rahul': 78, 'Priya': 88, 'Sonal': 90, 'Karan': 81}

# %%
students["Rahul"] = 56
students #4
# Out:
# {'Amit': 85, 'Neha': 92, 'Rahul': 56, 'Priya': 88, 'Sonal': 90, 'Karan': 81}

# %%
del students["Amit"]
students #5
# Out:
# {'Neha': 92, 'Rahul': 56, 'Priya': 88, 'Sonal': 90, 'Karan': 81}

# %%
print(students.keys()) #6
# Out:
# dict_keys(['Neha', 'Rahul', 'Priya', 'Sonal', 'Karan'])

# %%
print(students.values()) #7
# Out:
# dict_values([92, 56, 88, 90, 81])

# %%
print(students.items()) #8
# Out:
# dict_items([('Neha', 92), ('Rahul', 56), ('Priya', 88), ('Sonal', 90), ('Karan', 81)])

# %%
print("Priya" in students) #9
# Out:
# True

# %%
print(90 in students.values()) #10
# Out:
# True

# %%
print(students.get("Sonal"))#11
# Out:
# 90

# %%
employees = {
    "Ravi": "HR",
    "Anita": "IT",
    "Vikram": "Finance",
    "Pooja": "Marketing"
}

employees#12
# Out:
# {'Ravi': 'HR', 'Anita': 'IT', 'Vikram': 'Finance', 'Pooja': 'Marketing'}

# %%
print(employees["Anita"])#13
# Out:
# IT

# %%
employees["Suresh"] = "IT"#14
employees
# Out:
# {'Ravi': 'HR',
#  'Anita': 'IT',
#  'Vikram': 'Finance',
#  'Pooja': 'Marketing',
#  'Suresh': 'IT'}

# %%
employees["Ravi"] = "Admin"#15
employees
# Out:
# {'Ravi': 'Admin',
#  'Anita': 'IT',
#  'Vikram': 'Finance',
#  'Pooja': 'Marketing',
#  'Suresh': 'IT'}

# %%
del employees["Vikram"]
employees#16
# Out:
# {'Ravi': 'Admin', 'Anita': 'IT', 'Pooja': 'Marketing', 'Suresh': 'IT'}

# %%
print(dict(sorted(employees.items())))#17
# Out:
# {'Anita': 'IT', 'Pooja': 'Marketing', 'Ravi': 'Admin', 'Suresh': 'IT'}

# %%
print(dict(sorted(employees.items(), key=lambda x: x[1])))#18
# Out:
# {'Ravi': 'Admin', 'Anita': 'IT', 'Suresh': 'IT', 'Pooja': 'Marketing'}

# %%
print(dict(sorted(employees.items(), reverse=True)))#19
# Out:
# {'Suresh': 'IT', 'Ravi': 'Admin', 'Pooja': 'Marketing', 'Anita': 'IT'}

# %%
print(dict(sorted(employees.items(), key=lambda x: x[1], reverse=True)))#20
# Out:
# {'Pooja': 'Marketing', 'Anita': 'IT', 'Suresh': 'IT', 'Ravi': 'Admin'}

# %%
value_to_find = "IT"
print([k for k, v in employees.items() if v == value_to_find])#21
# Out:
# ['Anita', 'Suresh']

# %%
print(len([m for m in students.values() if m > 80]))#22
# Out:
# 4

# %%
student_details = {
    "Aman": {"age": 20, "grade": "A", "dept": "CS"},
    "Riya": {"age": 21, "grade": "B", "dept": "IT"},
    "Kunal": {"age": 19, "grade": "A", "dept": "ENTC"}
}

student_details#23
# Out:
# {'Aman': {'age': 20, 'grade': 'A', 'dept': 'CS'},
#  'Riya': {'age': 21, 'grade': 'B', 'dept': 'IT'},
#  'Kunal': {'age': 19, 'grade': 'A', 'dept': 'ENTC'}}

# %%
print(student_details["Aman"]["grade"])#24
# Out:
# A

# %%
student_details["Riya"]["dept"] = "CS"
student_details#25
# Out:
# {'Aman': {'age': 20, 'grade': 'A', 'dept': 'CS'},
#  'Riya': {'age': 21, 'grade': 'B', 'dept': 'CS'},
#  'Kunal': {'age': 19, 'grade': 'A', 'dept': 'ENTC'}}

# %%
for name, info in student_details.items():
    print(name, info["grade"])
#26
# Out:
# Aman A
# Riya B
# Kunal A

# %%
more_students = {
    "Mehul": 75,
    "Tina": 89
}
more_students
merged_students = {**students, **more_students}
print(merged_students)#27
# Out:
# {'Neha': 92, 'Rahul': 56, 'Priya': 88, 'Sonal': 90, 'Karan': 81, 'Mehul': 75, 'Tina': 89}

# %%
more_students.clear()
print(more_students)#28
# Out:
# {}

# %%
copy_students = students.copy()
copy_students["Neha"] = 95
print(students)
print(copy_students)#29
# Out:
# {'Neha': 92, 'Rahul': 56, 'Priya': 88, 'Sonal': 90, 'Karan': 81}
# {'Neha': 95, 'Rahul': 56, 'Priya': 88, 'Sonal': 90, 'Karan': 81}

# %%
squares = {i: i*i for i in range(1, 6)}
print(squares)#30
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
