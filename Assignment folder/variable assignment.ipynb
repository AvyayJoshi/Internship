# %%
#Assignment

# %%
# 1
def show_value():
    x = 10
    print(x)

show_value()
# Out:
# 10

# %%
# 2
def calculate_total():
    global total
    subtotal = 2420
    tax = 121.0
    discount = 242.0
    total = subtotal + tax - discount

calculate_total()
print(total)
# Out:
# 2299.0

# %%
# 3
count = 0

def inc():
    global count
    count += 1

def dec():
    global count
    count -= 1

inc()
inc()
dec()
print(count)
# Out:
# 1

# %%
# 4
total_sales = 0

def day1(a):
    global total_sales
    total_sales += a

def day2(a):
    global total_sales
    total_sales += a

day1(500)
day2(700)
print(total_sales)
# Out:
# 1200

# %%
# 5
def outer():
    x = 5
    def inner():
        print(x)
    inner()

outer()
# Out:
# 5

# %%
# 6
def outer():
    x = 10
    def inner():
        nonlocal x
        x += 5
    inner()
    print(x)

outer()
# Out:
# 15

# %%
# 7
g = "G"

def outer():
    e = "E"
    def mid():
        l = "L"
        print(g, e, l)
    mid()

outer()
# Out:
# G E L

# %%
# 8
x = 100

def show():
    x = 50
    print(x)

show()
print(x)
# Out:
# 50
# 100

# %%
# 9
x = "G"

def outer():
    x = "E"
    def inner():
        x = "L"
        print(x)
    inner()

outer()
# Out:
# L

# %%
# 10
def test():
    a = 10
    print(a)

test()
# Out:
# 10

# %%
# 11
def outer(a):
    def inner(b):
        print(a, b)
    inner(20)

outer(10)
# Out:
# 10 20

# %%
# 12
def marks(m1, m2, m3):
    def total():
        return m1 + m2 + m3
    print(total())

marks(70, 80, 90)
# Out:
# 240

# %%
# 13
def counter():
    c = 0
    def inc():
        nonlocal c
        c += 1
        return c
    return inc

x = counter()
print(x())
print(x())
# Out:
# 1
# 2

# %%
# 14
def multiplier(n):
    def mul(x):
        return x * n
    return mul

m = multiplier(2)
print(m(5))
# Out:
# 10

# %%
# 15
def total(*a):
    print(sum(a))

total(1, 2, 3, 4)
# Out:
# 10

# %%
# 16
def maximum(*a):
    print(max(a))

maximum(10, 20, 5, 30)
# Out:
# 30

# %%
# 17
def student(**d):
    print(d)

student(name="A", age=20, grade="A")
# Out:
# {'name': 'A', 'age': 20, 'grade': 'A'}

# %%
# 18
def employee(**d):
    print(d)

employee(name="J", department="IT", salary=50000)
# Out:
# {'name': 'J', 'department': 'IT', 'salary': 50000}

# %%
# 19
def details(*a, **k):
    print(a)
    print(k)

details(1, 2, name="S", age=25)
# Out:
# (1, 2)
# {'name': 'S', 'age': 25}

# %%
# 20
def avg(*a):
    print(sum(a)/len(a))

avg(100, 200, 300)
# Out:
# 200.0

# %%
# 21
def model(**k):
    print(k)

model(learning_rate=0.01, epochs=50)
# Out:
# {'learning_rate': 0.01, 'epochs': 50}

# %%
# 22
def outer():
    def inner(*a):
        print(sum(a))
    inner(1, 2, 3)

outer()
# Out:
# 6

# %%
# 23
def emp(name, salary):
    def bonus():
        return salary * 0.1
    print(bonus())

emp("R", 40000)
# Out:
# 4000.0

# %%
# 24
def counter():
    c = 0
    def call():
        nonlocal c
        c += 1
        print(c)
    return call

x = counter()
x()
x()
# Out:
# 1
# 2

# %%
# 25
x = "G"

def show():
    x = "L"
    print(x)

show()
print(x)
# Out:
# L
# G

# %%
# 26
def expense():
    t = 0
    def add(a):
        nonlocal t
        t += a
        return t
    return add

e = expense()
print(e(100))
print(e(200))
# Out:
# 100
# 300

# %%
# 27
def concat(*a):
    print("".join(a))

concat("Hello", "World")
# Out:
# HelloWorld

# %%
# 28
def config(**k):
    print(k)

config(OS="Windows", RAM="16GB")
# Out:
# {'OS': 'Windows', 'RAM': '16GB'}

# %%
# 29
def order(*i, **p):
    print(i)
    print(p)

order("Pen", "Book", Pen=10, Book=50)
# Out:
# ('Pen', 'Book')
# {'Pen': 10, 'Book': 50}

# %%
# 30
def salary(base):
    t = base
    def add(a):
        nonlocal t
        t += a
        return t
    return add

s = salary(30000)
print(s(5000))
print(s(2000))
# Out:
# 35000
# 37000
